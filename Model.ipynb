# %% [markdown]
# # Classification of Epileptical Seizures from EEG signals using Deep Learning

# %%
import tensorflow as tf
import numpy as np
from keras.models import Sequential
from keras.utils import np_utils
from keras.layers import Dense, Activation , LSTM , Dropout , AveragePooling3D
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# # Data Preprocessing

# %%
df=pd.read_csv('C:/Users/HP/Desktop/Project/Project Phase II/data.csv')
df.head()
# Out:
#    Unnamed: 0   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %%
X=df.values

# %%
X=X[:,1:-1]

# %%
from sklearn.model_selection import train_test_split


y=np.array(df['y'])
Y=np_utils.to_categorical(y)
Y.shape
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=1)

# %%
X_train = X_train.reshape(-1,178,1)
X_test = X_test.reshape(-1,178,1)


X_train.shape
X_test.shape
# Out:
# (2300, 178, 1)

# %% [markdown]
# #  Intuition of the Epileptical Signal In the Dataset

# %%
plt.figure(figsize=(12,8))
plt.plot(X[1,:],label='1')
plt.plot(X[7,:],label='2')
plt.plot(X[12,:],label='3')
plt.plot(X[0,:],label='4')
plt.plot(X[2,:],label='5')
plt.legend()
plt.show()

# %% [markdown]
# # Creating LSTM Neural Network For the Classification

# %%
model = Sequential()
model.add(LSTM(56, input_shape=(45,1), return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(56))
model.add(Dropout(0.3))
model.add(Dense(20))
model.add(Activation('tanh'))
model.add(Dense(5))
model.add(Activation('softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\HP\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\HP\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\HP\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\HP\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\HP\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 45, 56)            12992
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 45, 56)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 56)                25312
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 56)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                1140
# _________________________________________________________________
# activation_1 (Activation)    (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 105
# _________________________________________________________________
# activation_2 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 39,549
# Trainable params: 39,549
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\HP\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\HP\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3376: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From C:\Users\HP\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
hist = model.fit(((X_train[:,::4]-X_train.mean())/X_train.std()),Y_train[:,1:],validation_data=((X_test[:,::4]-X_test.mean())/X_test.std(),Y_test[:,1:])
                ,epochs = 50, batch_size=15,shuffle=False
                )
# Out:
# Train on 9200 samples, validate on 2300 samples
# Epoch 1/50
# 9200/9200 [==============================] - 88s 10ms/step - loss: 0.3994 - acc: 0.8304 - val_loss: 0.3880 - val_acc: 0.8328
# Epoch 2/50
# 9200/9200 [==============================] - 69s 7ms/step - loss: 0.3749 - acc: 0.8339 - val_loss: 0.3747 - val_acc: 0.8357
# Epoch 3/50
# 9200/9200 [==============================] - 75s 8ms/step - loss: 0.3310 - acc: 0.8452 - val_loss: 0.2885 - val_acc: 0.8565
# Epoch 4/50
# 9200/9200 [==============================] - 76s 8ms/step - loss: 0.2767 - acc: 0.8648 - val_loss: 0.2521 - val_acc: 0.8757
# Epoch 5/50
# 9200/9200 [==============================] - 70s 8ms/step - loss: 0.2529 - acc: 0.8733 - val_loss: 0.2456 - val_acc: 0.8752
# Epoch 6/50
# 9200/9200 [==============================] - 67s 7ms/step - loss: 0.2450 - acc: 0.8750 - val_loss: 0.2518 - val_acc: 0.8743
# Epoch 7/50
# 9200/9200 [==============================] - 61s 7ms/step - loss: 0.2395 - acc: 0.8765 - val_loss: 0.2355 - val_acc: 0.8770
# Epoch 8/50
# 9200/9200 [==============================] - 50s 5ms/step - loss: 0.2349 - acc: 0.8780 - val_loss: 0.2319 - val_acc: 0.8832
# Epoch 9/50
# 9200/9200 [==============================] - 52s 6ms/step - loss: 0.2356 - acc: 0.8772 - val_loss: 0.2280 - val_acc: 0.8827
# Epoch 10/50
# 9200/9200 [==============================] - 50s 5ms/step - loss: 0.2305 - acc: 0.8808 - val_loss: 0.2282 - val_acc: 0.8802
# Epoch 11/50
# 9200/9200 [==============================] - 50s 5ms/step - loss: 0.2259 - acc: 0.8814 - val_loss: 0.2290 - val_acc: 0.8814
# Epoch 12/50
# 9200/9200 [==============================] - 53s 6ms/step - loss: 0.2255 - acc: 0.8838 - val_loss: 0.2292 - val_acc: 0.8818
# Epoch 13/50
# 9200/9200 [==============================] - 52s 6ms/step - loss: 0.2204 - acc: 0.8850 - val_loss: 0.2253 - val_acc: 0.8837
# Epoch 14/50
# 9200/9200 [==============================] - 48s 5ms/step - loss: 0.2186 - acc: 0.8860 - val_loss: 0.2188 - val_acc: 0.8886
# Epoch 15/50
# 9200/9200 [==============================] - 54s 6ms/step - loss: 0.2153 - acc: 0.8873 - val_loss: 0.2193 - val_acc: 0.8877
# Epoch 16/50
# 9200/9200 [==============================] - 51s 6ms/step - loss: 0.2131 - acc: 0.8884 - val_loss: 0.2265 - val_acc: 0.8864
# Epoch 17/50
# 9200/9200 [==============================] - 50s 5ms/step - loss: 0.2136 - acc: 0.8890 - val_loss: 0.2169 - val_acc: 0.8869
# Epoch 18/50
# 9200/9200 [==============================] - 47s 5ms/step - loss: 0.2106 - acc: 0.8915 - val_loss: 0.2243 - val_acc: 0.8857
# Epoch 19/50
# 9200/9200 [==============================] - 45s 5ms/step - loss: 0.2099 - acc: 0.8898 - val_loss: 0.2187 - val_acc: 0.8868
# Epoch 20/50
# 9200/9200 [==============================] - 49s 5ms/step - loss: 0.2080 - acc: 0.8930 - val_loss: 0.2152 - val_acc: 0.8888
# Epoch 21/50
# 9200/9200 [==============================] - 56s 6ms/step - loss: 0.2050 - acc: 0.8951 - val_loss: 0.2121 - val_acc: 0.8889
# Epoch 22/50
# 9200/9200 [==============================] - 49s 5ms/step - loss: 0.2034 - acc: 0.8940 - val_loss: 0.2084 - val_acc: 0.8917
# Epoch 23/50
# 9200/9200 [==============================] - 46s 5ms/step - loss: 0.2014 - acc: 0.8965 - val_loss: 0.2122 - val_acc: 0.8890
# Epoch 24/50
# 9200/9200 [==============================] - 46s 5ms/step - loss: 0.2015 - acc: 0.8947 - val_loss: 0.2115 - val_acc: 0.8894
# Epoch 25/50
# 9200/9200 [==============================] - 49s 5ms/step - loss: 0.1995 - acc: 0.8970 - val_loss: 0.2125 - val_acc: 0.8916
# Epoch 26/50
# 9200/9200 [==============================] - 51s 6ms/step - loss: 0.1974 - acc: 0.8988 - val_loss: 0.2133 - val_acc: 0.8901
# Epoch 27/50
# 9200/9200 [==============================] - 51s 6ms/step - loss: 0.1976 - acc: 0.8981 - val_loss: 0.2069 - val_acc: 0.8928
# Epoch 28/50
# 9200/9200 [==============================] - 56s 6ms/step - loss: 0.1917 - acc: 0.9028 - val_loss: 0.2098 - val_acc: 0.8901
# Epoch 29/50
# 9200/9200 [==============================] - 51s 6ms/step - loss: 0.1923 - acc: 0.9015 - val_loss: 0.2199 - val_acc: 0.8879
# Epoch 30/50
# 9200/9200 [==============================] - 50s 5ms/step - loss: 0.1891 - acc: 0.9024 - val_loss: 0.2118 - val_acc: 0.8907
# Epoch 31/50
# 9200/9200 [==============================] - 50s 5ms/step - loss: 0.1877 - acc: 0.9050 - val_loss: 0.2141 - val_acc: 0.8919
# Epoch 32/50
# 9200/9200 [==============================] - 49s 5ms/step - loss: 0.1888 - acc: 0.9043 - val_loss: 0.2179 - val_acc: 0.8903
# Epoch 33/50
# 9200/9200 [==============================] - 53s 6ms/step - loss: 0.1836 - acc: 0.9056 - val_loss: 0.2124 - val_acc: 0.8917oss: 0
# Epoch 34/50
# 9200/9200 [==============================] - 55s 6ms/step - loss: 0.1858 - acc: 0.9049 - val_loss: 0.2189 - val_acc: 0.8887
# Epoch 35/50
# 9200/9200 [==============================] - 51s 6ms/step - loss: 0.1833 - acc: 0.9069 - val_loss: 0.2148 - val_acc: 0.8929
# Epoch 36/50
# 9200/9200 [==============================] - 49s 5ms/step - loss: 0.1812 - acc: 0.9076 - val_loss: 0.2128 - val_acc: 0.8923
# Epoch 37/50
# 9200/9200 [==============================] - 51s 6ms/step - loss: 0.1844 - acc: 0.9062 - val_loss: 0.2135 - val_acc: 0.8943
# Epoch 38/50
# 9200/9200 [==============================] - 51s 6ms/step - loss: 0.1823 - acc: 0.9091 - val_loss: 0.2127 - val_acc: 0.8903
# Epoch 39/50
# 9200/9200 [==============================] - 51s 6ms/step - loss: 0.1761 - acc: 0.9118 - val_loss: 0.2061 - val_acc: 0.8974
# Epoch 40/50
# 9200/9200 [==============================] - 55s 6ms/step - loss: 0.1753 - acc: 0.9112 - val_loss: 0.2134 - val_acc: 0.8937
# Epoch 41/50
# 9200/9200 [==============================] - 51s 6ms/step - loss: 0.1762 - acc: 0.9106 - val_loss: 0.2090 - val_acc: 0.8941
# Epoch 42/50
# 9200/9200 [==============================] - 47s 5ms/step - loss: 0.1746 - acc: 0.9140 - val_loss: 0.2200 - val_acc: 0.8930
# Epoch 43/50
# 9200/9200 [==============================] - 48s 5ms/step - loss: 0.1735 - acc: 0.9127 - val_loss: 0.2091 - val_acc: 0.9012
# Epoch 44/50
# 9200/9200 [==============================] - 48s 5ms/step - loss: 0.1715 - acc: 0.9147 - val_loss: 0.2119 - val_acc: 0.8981
# Epoch 45/50
# 9200/9200 [==============================] - 49s 5ms/step - loss: 0.1711 - acc: 0.9147 - val_loss: 0.2082 - val_acc: 0.8983
# Epoch 46/50
# 9200/9200 [==============================] - 50s 5ms/step - loss: 0.1676 - acc: 0.9163 - val_loss: 0.2159 - val_acc: 0.8944
# Epoch 47/50
# 9200/9200 [==============================] - 55s 6ms/step - loss: 0.1674 - acc: 0.9164 - val_loss: 0.2177 - val_acc: 0.8950
# Epoch 48/50
# 9200/9200 [==============================] - 49s 5ms/step - loss: 0.1691 - acc: 0.9150 - val_loss: 0.2180 - val_acc: 0.8998
# Epoch 49/50
# 9200/9200 [==============================] - 49s 5ms/step - loss: 0.1630 - acc: 0.9178 - val_loss: 0.2136 - val_acc: 0.9017
# Epoch 50/50
# 9200/9200 [==============================] - 49s 5ms/step - loss: 0.1621 - acc: 0.9186 - val_loss: 0.2263 - val_acc: 0.8937

# %% [markdown]
# # Saving The Trained Model

# %%
model.save('Epilepsy.h5')

# %% [markdown]
# # Visualisations

# %% [markdown]
# Graph Between Training Loss and Training Accuracy

# %%
plt.figure(0)
plt.plot(hist.history['loss'],'g')
plt.plot(hist.history['acc'],'r')
plt.show()

# %% [markdown]
# Graph Between Validation Loss Function and Validation Accuracy

# %%
plt.figure(0)
plt.plot(hist.history['val_loss'],'b')
plt.plot(hist.history['val_acc'],'black')
plt.show()
